# %% [markdown]
# #### Pandas conti....

# %% [markdown]
# ##### DataFrame
# * It is two dimensional data

# %%
#to create DataFrame
import pandas as pd

# %%
df=([['vidya','28','gec'],['sree','40','PVP']])
df1=pd.DataFrame(df,columns=['name','rollnumber','clg'])

# %%
df1
# Out:
#     name rollnumber  clg
# 0  vidya         28  gec
# 1   sree         40  PVP

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#        0   1    2
# 0  vidya  28  gec
# 1   sree  40  PVP

# %%
#dictionary
d1={"name":"abc","clg":"gec","branch":"civil","rollno":28}
d2={"name":"def","clg":"VRSEC","branch":"cse",}
d3={"name":"ghi","branch":"ECE","rollno":27}
s=pd.DataFrame([d1,d2,d3],index=[1,2,3])

# %%
s
# Out:
#   branch    clg name  rollno
# 1  civil    gec  abc    28.0
# 2    cse  VRSEC  def     NaN
# 3    ECE    NaN  ghi    27.0

# %%
s["email"]=["abc@gmail.com","def@gmail.com","ghi@gmail.com"]

# %%
s
# Out:
#   branch    clg name  rollno          email
# 1  civil    gec  abc    28.0  abc@gmail.com
# 2    cse  VRSEC  def     NaN  def@gmail.com
# 3    ECE    NaN  ghi    27.0  ghi@gmail.com

# %%
s
# Out:
#   branch    clg name  rollno          email
# 1  civil    gec  abc    28.0  abc@gmail.com
# 2    cse  VRSEC  def     NaN  def@gmail.com
# 3    ECE    NaN  ghi    27.0  ghi@gmail.com

# %%
s1=s.reset_index()
s1['clg']=pd.Series({0:'gec',2:'NaN'})

# %%
s1
# Out:
#    index branch  clg name  rollno          email
# 0      1  civil  gec  abc    28.0  abc@gmail.com
# 1      2    cse  NaN  def     NaN  def@gmail.com
# 2      3    ECE  NaN  ghi    27.0  ghi@gmail.com

# %%
df=pd.DataFrame([{"Name":"chris","Itempurchased":"cakes","Cost":22.5},
                {"Name":"john","Itempurchased":"choclate","Cost":30},
                {"Name":"filip","Itempurchased":"fruits","Cost":40}],index=['store1','store1','store3'])

# %%
df
# Out:
#         Cost Itempurchased   Name
# store1  22.5         cakes  chris
# store1  30.0      choclate   john
# store3  40.0        fruits  filip

# %%
#to create another column
df["Date"]=["july 16","may 7","april 18"]

# %%
df
# Out:
#         Cost Itempurchased   Name      Date
# store1  22.5         cakes  chris   july 16
# store1  30.0      choclate   john     may 7
# store3  40.0        fruits  filip  april 18

# %%
df["feedback"]=["Positive",None,"Negative"]

# %%
df
# Out:
#         Cost Itempurchased   Name      Date  feedback
# store1  22.5         cakes  chris   july 16  Positive
# store1  30.0      choclate   john     may 7      None
# store3  40.0        fruits  filip  april 18  Negative

# %%
#loc----->to give index data
#ioc---->to give index value

# %%
df
# Out:
#    level_0   index  Cost Itempurchased   Name      Date  feedback    clg
# 0        0  store1  22.5         cakes  chris   july 16  Positive  chris
# 1        1  store1  30.0      choclate   john     may 7      None    NaN
# 2        2  store3  40.0        fruits  filip  april 18  Negative  filip

# %%
df
# Out:
#         Cost Itempurchased   Name      Date  feedback
# store1  22.5         cakes  chris   july 16  Positive
# store1  30.0      choclate   john     may 7      None
# store3  40.0        fruits  filip  april 18  Negative

# %%
df1=df.reset_index()
df1['Date']=pd.Series({0:'july16',2:'april18'})
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-1822f7857027> in <module>
# ----> 1 df1=df.reset_index()
#       2 df1['Date']=pd.Series({0:'july16',2:'april18'})
#       3 df1
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# ...

# %%
df.loc['store1']
# Out:
#         Cost Itempurchased   Name     Date  feedback
# store1  22.5         cakes  chris  july 16  Positive
# store1  30.0      choclate   john    may 7      None

# %%
df.iloc[0]
# Out:
# Cost                 22.5
# Itempurchased       cakes
# Name                chris
# Date              july 16
# feedback         Positive
# Name: store1, dtype: object

# %%
df
# Out:
#    level_0   index  Cost Itempurchased   Name      Date  feedback    clg
# 0        0  store1  22.5         cakes  chris   july 16  Positive  chris
# 1        1  store1  30.0      choclate   john     may 7      None    NaN
# 2        2  store3  40.0        fruits  filip  april 18  Negative  filip

# %%
#function to read csv file
def Csvfile(fpath):
    return pd.read_csv(fpath)
fpath="income.csv"
Csvfile(fpath)
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
fpath="income.csv"
income1=pd.read_csv(fpath)
income1
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
income=Csvfile(fpath)

# %%
income
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
#to print all column names
for i in income.columns:
    print(i,end=" ")
# Out:
# GEOID State 2005 2006 2007 2008 2009 2010 2011 2012 2013

# %%
for i in income.keys():
    print(i,end=" ")
# Out:
# GEOID State 2005 2006 2007 2008 2009 2010 2011 2012 2013

# %%
for i in income.values:
    print(i)
# Out:
# ['04000US01' 'Alabama' 37150 37952 42212 44476 39980 40933 42590 43464
#  41381]
# ['04000US02' 'Alaska' 55891 56418 62993 63989 61604 57848 57431 63648
#  61137]
# ['04000US04' 'Arizona' 45245 46657 62993 46914 45739 46896 48621 47044
#  50602]
# ['04000US05' 'Arkansas' 36658 37057 40795 39586 36538 38587 41302 39018
#  39919]
# ['04000US06' 'California' 51755 55319 55734 57014 56134 54283 53367 57020
#  57528]

# %%
income
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
income.iloc[1:11]
# Out:
#        GEOID       State   2005   2006   2007   2008   2009   2010   2011  \
# 1  04000US02      Alaska  55891  56418  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657  62993  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319  55734  57014  56134  54283  53367
#
#     2012   2013
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
or
